# %% [markdown]
# 选择一个API的数据进行实验，确保分类之后pn_sim要比分类前pu_sim明显降低

# %%
import os
import re
import pandas as pd
import numpy as np
import api_tags_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.decomposition import TruncatedSVD
from scipy.sparse import vstack
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

data_path = 'DATA/clean_API_data/'
file_list = os.listdir(data_path)
for i in range(len(file_list)):
    print(i, file_list[i])
# Out:
# 0 clean_google-checkout.csv
# 1 clean_google-adwords.csv
# 2 clean_wurfl.csv
# 3 clean_deezer.csv
# 4 clean_itunes-and-itunes-connect.csv
# 5 clean_musicbrainz.csv
# 6 clean_facebook.csv
# 7 clean_zipcode.csv
# 8 clean_google-directions.csv
# 9 clean_flickr.csv
# 10 clean_dailymotion.csv
# 11 clean_mailgun.csv
# 12 clean_tumblr.csv
# 13 clean_mapbox.csv
# 14 clean_lastfm.csv
# 15 clean_yahoo-mail.csv
# 16 clean_amazon-s3.csv
# 17 clean_aws-cloud9.csv
# 18 clean_twitter.csv
# 19 clean_reddit.csv
# 20 clean_brightcove.csv
# 21 clean_pinterest.csv
# 22 clean_twilio.csv
# 23 clean_woocommerce.csv
# 24 clean_geocoder.csv
# 25 clean_cartodb.csv
# 26 clean_google-cloud-sql.csv
# 27 clean_coupon.csv
# 28 clean_google-adsense.csv
# 29 clean_soundcloud.csv
# 30 clean_gravatar.csv
# 31 clean_google-earth.csv
# 32 clean_google-fusion-tables.csv
# 33 clean_google-cloud-dns.csv
# 34 clean_google-plus.csv
# 35 clean_openlayers.csv
# 36 clean_plunker.csv
# 37 clean_google-maps-android.csv
# 38 clean_ilist.csv
# 39 clean_allegro.csv
# 40 clean_openstreetmap.csv
# 41 clean_paypal.csv
# 42 clean_digitalocean.csv
# 43 clean_facebook-ads.csv
# 44 clean_rackspace-cloud-servers.csv
# 45 clean_urban-airship.csv
# 46 clean_2checkout.csv
# 47 clean_amazon-sns.csv
# 48 clean_imgur.csv
# 49 clean_breadcrumbs.csv
# 50 clean_bigcommerce.csv
# 51 clean_marketo.csv
# 52 clean_youtube.csv
# 53 clean_heroku.csv
# 54 clean_amazon-queue-service.csv
# 55 clean_mailjet.csv
# 56 clean_mandrill.csv
# 57 clean_instagram-graph.csv
# 58 clean_opensocial.csv
# 59 clean_recurly.csv
# 60 clean_openstack.csv
# 61 clean_pubnub.csv
# 62 clean_bing-maps.csv
# 63 clean_eventbrite.csv
# 64 clean_foursquare.csv
# 65 clean_plivo.csv
# 66 clean_google-mirror.csv
# 67 clean_google-maps-places.csv
# 68 clean_telegram-bot.csv
# 69 clean_sendgrid.csv
# 70 clean_amazon-ses.csv
# 71 clean_coinbase.csv
# 72 clean_onelogin.csv
# 73 clean_google-app-engine.csv
# 74 clean_linkedin.csv
# 75 clean_mixer.csv
# 76 clean_vimeo.csv
# 77 clean_payments-gateway.csv
# 78 clean_yammer.csv
# 79 clean_sms.csv
# 80 clean_authorizenet.csv
# 81 clean_buffer.csv
# 82 clean_heatmap.csv
# 83 clean_xero.csv
# 84 clean_google-cloud-print.csv
# 85 clean_multimap.csv
# 86 clean_google-static-maps.csv
# 87 clean_google-drive.csv
# 88 clean_rhapsody.csv
# 89 clean_vk.csv
# 90 clean_google-street-view-image.csv
# 91 clean_google-geocoding.csv
# 92 clean_stripe.csv
# 93 clean_gmail.csv
# 94 clean_google-distance-matrix.csv
# 95 clean_admob.csv
# 96 clean_google-picasa.csv
# 97 clean_amazon-ec2.csv
# 98 clean_google-maps.csv
# 99 clean_dropbox.csv
# 100 clean_mapquest.csv
# 101 clean_mailchimp.csv
# 102 clean_geonames.csv
# 103 clean_servicenow.csv
# 104 clean_openx.csv

# %%
pt_dic = {}
f = open('DATA/API_PT.txt', 'r')
for line in f.readlines():
    print(line)
    words = re.split('\t', line.strip())
    pt_dic[words[0]] = words[1]
# Out:
# 2checkout	2checkout
#
# admob	admob
#
# allegro	allegro
#
# amazon-ec2	amazon-ec2
#
# amazon-queue-service	amazon-sqs
#
# amazon-s3	amazon-s3
#
# amazon-ses	amazon-ses
#
# amazon-sns	amazon-sns
#
# authorizenet	authorize.net
#
# aws-cloud9	aws-cloud9
#
# bigcommerce	bigcommerce
#
# bing-maps	bing-maps
#
# breadcrumbs	breadcrumbs
#
# brightcove	brightcove
#
# buffer	buffer
#
# cartodb	cartodb
#
# coinbase	coinbase-api
#
# coupon	coupon
#
# dailymotion	dailymotion-api
#
# deezer	deezer
#
# digitalocean	digital-ocean
#
# dropbox	dropbox-api
#
# eventbrite	eventbrite
#
# facebook-ads	facebook-ads-api
#
# facebook	facebook
#
# flickr	flickr
#
# foursquare	foursquare
#
# geocoder	google-geocoder
#
# geonames	geonames
#
# gmail	gmail-api
#
# google-adsense	adsense-api
#
# google-adwords	google-adwords
#
# google-app-engine	google-app-engine
#
# google-checkout	google-checkout
#
# google-cloud-dns	google-cloud-dns
#
# google-cloud-print	google-cloud-print
#
# google-cloud-sql	google-cloud-sql
#
# google-directions	google-direction
#
# google-distance-matrix	google-distancematrix-api
#
# google-drive	google-drive-sdk
#
# google-earth	google-earth
#
# google-fusion-tables	google-fusion-tables
#
# google-geocoding	google-geocoding-api
#
# google-maps-android	google-maps-android-api-2
#
# google-maps-places	google-places-api
#
# google-maps	google-maps
#
# google-mirror	google-mirror-api
#
# google-picasa	picasa
#
# google-plus	google-plus
#
# google-static-maps	google-static-maps
#
# google-street-view-image	google-street-view
#
# gravatar	gravatar
#
# heatmap	heatmap
#
# heroku	heroku
#
# ilist	ilist
#
# imgur	imgur
#
# instagram-graph	instagram-graph-api
#
# itunes-and-itunes-connect	itunesconnect
#
# lastfm	last.fm
#
# linkedin	linkedin-api
#
# mailchimp	mailchimp
#
# mailgun	mailgun
#
# mailjet	mailjet
#
# mandrill	mandrill
#
# mapbox	mapbox
#
# mapquest	mapquest
#
# marketo	marketo
#
# mixer	mixer
#
# multimap	multimap
#
# musicbrainz	musicbrainz
#
# onelogin	onelogin
#
# openlayers	openlayers
#
# opensocial	opensocial
#
# openstack	openstack
#
# openstreetmap	openstreetmap
#
# openx	openx
#
# payments-gateway	payment-gateway
#
# paypal	paypal
#
# pinterest	pinterest
#
# plivo	plivo
#
# plunker	plunker
#
# pubnub	pubnub
#
# rackspace-cloud-servers	rackspace-cloud
#
# recurly	recurly
#
# reddit	reddit
#
# rhapsody	rhapsody
#
# sendgrid	sendgrid
#
# servicenow	servicenow
#
# sms	sms
#
# soundcloud	soundcloud
#
# stripe	stripe-payments
#
# telegram-bot	telegram-bot
#
# tumblr	tumblr
#
# twilio	twilio-api
#
# twitter	twitter
#
# urban-airship	urbanairship.com
#
# vimeo	vimeo-api
#
# vk	vk
#
# woocommerce	woocommerce
#
# wurfl	wurfl
#
# xero	xero-api
#
# yahoo-mail	yahoo-mail
#
# yammer	yammer
#
# youtube	youtube-api
#
# zipcode	zipcode

# %%
def get_clean_tags(tags, ptag):
    result = ''
    for ele in tags:
        if ele != ptag:
            result = result + ele[1:-1] + ' '
    if result == '':
        return result
    else:
        return result[:-1]

# %%
def text_list(df, ptag):
    pos_text = []
    unl_text = []
    p_line_dic = {}
    n_line_dic = {}
    oneptline = []
    p = 0
    n = 0
    
    for i in range(df.shape[0]):
        tags = df.iloc[i]['Tags']
        tags = re.findall('<.*?>', tags, re.S)
        if ptag in tags:
            clean_tags = get_clean_tags(tags, ptag)
            if clean_tags != '':
                pos_text.append(clean_tags)
                p_line_dic[p] = i
                p += 1
            else:
                oneptline.append(i)
        else:
            n_line_dic[n] = i
            n += 1
            unl_text.append(get_clean_tags(tags, ptag))
    return pos_text, unl_text, p_line_dic, n_line_dic, oneptline

# %%
def Vector(pos_text, unl_text):
    tfidf = TfidfVectorizer()
    corpus = pos_text + unl_text
    corpus_v = tfidf.fit_transform(corpus)
    
    labels = [1]*len(pos_text)
    labels += [0]*len(unl_text)
    labels = np.array(labels)
    np.reshape(labels, (labels.shape[0], 1))
    y = pd.Series(labels)
    return corpus, corpus_v, y

# %%
def PUalgo(corpus_v, y):
    ## Step 1: NB
    iP = y[y == 1].index
    iU = y[y == 0].index
    #corpus_v = corpus_v.toarray()
    
    n_com = min(500, corpus_v.shape[1])
    n_com = min(n_com, corpus_v.shape[0]-1)
    svd = TruncatedSVD(n_components=n_com-1, n_iter=10, random_state=0)
    svd.fit(corpus_v)
    corpus_v1 = svd.transform(corpus_v)
    print("After SVD, the vector shape: ", corpus_v1.shape)
    
    gnb = GaussianNB()
    gnb.fit(corpus_v1, y.values)
    u_pred = gnb.predict(corpus_v1[iU])
    iRN = iU[u_pred==0]
    if len(iRN) == 0:
        print(" No relible NEG. All iUs are POS.")
        return iP, iU, iRN
    
    ## Step 2: SVM
    cnt = 1
    print("  Running:", end="")
    while True:
        #print(" PU_Epoch:%d" % cnt)
        cnt += 1
        print("=", end="")
        
        iQ = list(set(iU) - set(iRN))
        #print("  iU, iRN, iQ: ", len(iU), len(iRN), len(iQ))
        if len(iQ) == 0:
            print("  \nNo iQ. All iUs are NEG.")
            return iP, iQ, iRN
        iQ = np.array(iQ)
        ##Xt = np.append(corpus_v[iP], corpus_v[iRN], axis=0)
        Xt = vstack((corpus_v[iP], corpus_v[iRN]))
        yt = y[iP].append(y[iRN])
        #print("X_shape, y_shape: ", Xt.shape, yt.shape)
        clf = SVC(gamma='scale')
        #clf = tree.DecisionTreeClassifier()
        #clf = RandomForestClassifier(n_estimators=10)
        #clf = AdaBoostClassifier()
        #clf = GaussianNB()
        clf.fit(Xt, yt)
    
        pred = clf.predict(corpus_v[iQ])
        iW = iQ[pred == 0]
        if len(iW) == 0:
            print("\n  No iW. All iQs are POS.")
            print("  iU, iRN, iQ: ", len(iU), len(iRN), len(iQ))
            scores = clf.score(corpus_v[iP], y[iP])
            print("  The model score on POS samples is %f" % scores)
            return iP, iQ, iRN
        else:
            #print("  Negs in iQ: ", len(iW))
            iRN = np.append(iRN, iW)

# %%
def check_sim(pos_text, unl_text, iP, iQ, iRN):
    corpus = pos_text + unl_text
    
    finalP = []
    finalN = []
    finalp1 = []
    finalp2 = []

    for i in iRN:
        finalN.append(corpus[i])

    for i in range(len(iP)):
        finalP.append(corpus[iP[i]])
        if i%2 == 0:
            finalp1.append(corpus[iP[i]])
        else:
            finalp2.append(corpus[iP[i]])
    for i in range(len(iQ)):
        finalP.append(corpus[iQ[i]])
        if i%2 == 0:
            finalp1.append(corpus[iQ[i]])
        else:
            finalp2.append(corpus[iQ[i]])
    
    sim0 = api_tags_similarity.cal_list_sim(finalP, finalN)
    sim1 = api_tags_similarity.cal_list_sim(finalp1, finalp2)
    return sim0, sim1

# %%
def savefile(save_path, apiname, df, p_line_dic, n_line_dic, oneptline, iP, iQ):
    pdf = pd.DataFrame()
    PID = {}
    for i in oneptline:
        PID[i] = 1
    for i in iP:
        PID[p_line_dic[i]] = 1
    nP = len(iP)
    for i in iQ:
        PID[n_line_dic[i-nP]] = 1
    plist = sorted(PID)
    for i in plist:
        ele = pd.DataFrame(df.iloc[i]).T
        pdf = pdf.append([ele])
    pdf.to_csv(save_path+apiname+'_R.csv',index=False,sep=',')
    print(" Relative CSV shape: ", pdf.shape)

# %%
save_path = 'DATA/relative_api_data1/'
for index in range(0, len(pt_dic)):
    apiname = file_list[index][6:-4]
    ptag = '<' + pt_dic[apiname] + '>'
    print(index, apiname, ptag)
    df = pd.read_csv(data_path+file_list[index])
    print(' ', df.shape)
    pos_text, unl_text, p_line_dic, n_line_dic, oneptline = text_list(df, ptag)
    print(" PosN: %d, UnlN: %d" % (len(pos_text), len(unl_text)))
    corpus, corpus_v, y = Vector(pos_text, unl_text)
    print(" Vector shape: ", corpus_v.shape)
    iP, iQ, iRN = PUalgo(corpus_v, y)
    
    sim_pu0 = api_tags_similarity.api_tag_sim(df, ptag)
    sim_pp0 = api_tags_similarity.api_tag_sim_pp(df, ptag)
    print(" Simpu0=%f\tSimpp0=%f" % (sim_pu0, sim_pp0))
    sim_pn1, sim_pp1 = check_sim(pos_text, unl_text, iP, iQ, iRN)
    print(" Simpn1=%f\tSimpp1=%f" % (sim_pn1, sim_pp1))
    savefile(save_path, apiname, df, p_line_dic, n_line_dic, oneptline, iP, iQ)
    print("\n")
# Out:
# 0 admob <admob>
#   (9345, 15)
#  PosN: 7279, UnlN: 1906
#  Vector shape:  (9185, 1248)
# After SVD, the vector shape:  (9185, 499)
#   Running:==
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  1906 1631 275
#   The model score on POS samples is 0.996703
#  Simpu0=0.987634	Simpp0=0.999138
#  Simpn1=0.983138	Simpp1=0.999193
#  Relative CSV shape:  (7714, 15)
#
#
# 1 yahoo-mail <yahoo-mail>
#   (3626, 15)
#  PosN: 135, UnlN: 3487
#  Vector shape:  (3622, 1407)
# After SVD, the vector shape:  (3622, 499)
#   Running:=====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  3487 3479 8
#   The model score on POS samples is 0.037037
#  Simpu0=0.889959	Simpp0=0.906461
#  Simpn1=0.881093	Simpp1=0.901620
#  Relative CSV shape:  (147, 15)
#
#
# 2 payments-gateway <payment-gateway>
#   (6793, 15)
#  PosN: 3073, UnlN: 3662
#  Vector shape:  (6735, 1531)
# After SVD, the vector shape:  (6735, 499)
#   Running:========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  3662 1431 2231
#   The model score on POS samples is 0.956069
#  Simpu0=0.917585	Simpp0=0.991948
#  Simpn1=0.862606	Simpp1=0.996121
#  Relative CSV shape:  (5362, 15)
#
#
# 3 wurfl <wurfl>
#   (190, 15)
#  PosN: 105, UnlN: 76
#  Vector shape:  (181, 187)
# After SVD, the vector shape:  (181, 179)
#   Running:==
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  76 66 10
#   The model score on POS samples is 0.952381
#  Simpu0=0.888981	Simpp0=0.867917
#  Simpn1=0.820417	Simpp1=0.865363
#  Relative CSV shape:  (124, 15)
#
#
# 4 zipcode <zipcode>
#   (3706, 15)
#  PosN: 348, UnlN: 3353
#  Vector shape:  (3701, 1747)
# After SVD, the vector shape:  (3701, 499)
#   Running:=========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  3353 3252 101
#   The model score on POS samples is 0.376437
#  Simpu0=0.789130	Simpp0=0.896626
#  Simpn1=0.713352	Simpp1=0.913337
#  Relative CSV shape:  (454, 15)
#
#
# 5 youtube <youtube-api>
#   (45527, 15)
#  PosN: 8442, UnlN: 36315
#  Vector shape:  (44757, 6211)
# After SVD, the vector shape:  (44757, 499)
#   Running:================
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  36315 28557 7758
#   The model score on POS samples is 0.743900
#  Simpu0=0.888934	Simpp0=0.998182
#  Simpn1=0.909027	Simpp1=0.999252
#  Relative CSV shape:  (16970, 15)
#
#
# 6 bing-maps <bing-maps>
#   (3333, 15)
#  PosN: 2254, UnlN: 916
#  Vector shape:  (3170, 1216)
# After SVD, the vector shape:  (3170, 499)
#   Running:====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  916 495 421
#   The model score on POS samples is 0.994676
#  Simpu0=0.884686	Simpp0=0.989057
#  Simpn1=0.761090	Simpp1=0.989629
#  Relative CSV shape:  (2838, 15)
#
#
# 7 servicenow <servicenow>
#   (680, 15)
#  PosN: 456, UnlN: 102
#  Vector shape:  (558, 477)
# After SVD, the vector shape:  (558, 476)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  102 101 1
#   The model score on POS samples is 1.000000
#  Simpu0=0.799822	Simpp0=0.910774
#  Simpn1=0.791363	Simpp1=0.922810
#  Relative CSV shape:  (579, 15)
#
#
# 8 yammer <yammer>
#   (806, 15)
#  PosN: 437, UnlN: 112
#  Vector shape:  (549, 388)
# After SVD, the vector shape:  (549, 387)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  112 100 12
#   The model score on POS samples is 0.990847
#  Simpu0=0.547900	Simpp0=0.921762
#  Simpn1=0.485566	Simpp1=0.954095
#  Relative CSV shape:  (706, 15)
#
#
# 9 google-picasa <picasa>
#   (882, 15)
#  PosN: 415, UnlN: 455
#  Vector shape:  (870, 630)
# After SVD, the vector shape:  (870, 499)
#   Running:==
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  455 295 160
#   The model score on POS samples is 0.983133
#  Simpu0=0.852431	Simpp0=0.928634
#  Simpn1=0.753512	Simpp1=0.940360
#  Relative CSV shape:  (587, 15)
#
#
# 10 google-adsense <adsense-api>
#   (2288, 15)
#  PosN: 81, UnlN: 2191
#  Vector shape:  (2272, 856)
# After SVD, the vector shape:  (2272, 499)
#   Running:====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  2191 1998 193
#   The model score on POS samples is 0.629630
#  Simpu0=0.877079	Simpp0=0.942892
#  Simpn1=0.855759	Simpp1=0.990128
#  Relative CSV shape:  (290, 15)
#
#
# 11 heatmap <heatmap>
#   (4933, 15)
#  PosN: 2408, UnlN: 2513
#  Vector shape:  (4921, 1370)
# After SVD, the vector shape:  (4921, 499)
#   Running:======
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  2513 964 1549
#   The model score on POS samples is 0.963455
#  Simpu0=0.958020	Simpp0=0.995331
#  Simpn1=0.840487	Simpp1=0.997008
#  Relative CSV shape:  (3969, 15)
#
#
# 12 google-distance-matrix <google-distancematrix-api>
#   (785, 15)
#  PosN: 263, UnlN: 493
#  Vector shape:  (756, 411)
# After SVD, the vector shape:  (756, 410)
#   Running:========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  493 274 219
#   The model score on POS samples is 0.927757
#  Simpu0=0.954011	Simpp0=0.962899
#  Simpn1=0.916756	Simpp1=0.985225
#  Relative CSV shape:  (511, 15)
#
#
# 13 cartodb <cartodb>
#   (221, 15)
#  PosN: 144, UnlN: 69
#  Vector shape:  (213, 205)
# After SVD, the vector shape:  (213, 204)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  69 67 2
#   The model score on POS samples is 0.951389
#  Simpu0=0.851684	Simpp0=0.840327
#  Simpn1=0.846418	Simpp1=0.834058
#  Relative CSV shape:  (154, 15)
#
#
# 14 amazon-sns <amazon-sns>
#   (1831, 15)
#  PosN: 1502, UnlN: 291
#  Vector shape:  (1793, 528)
# After SVD, the vector shape:  (1793, 499)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  291 161 130
#   The model score on POS samples is 0.999334
#  Simpu0=0.973719	Simpp0=0.996962
#  Simpn1=0.942340	Simpp1=0.996313
#  Relative CSV shape:  (1670, 15)
#
#
# 15 google-cloud-sql <google-cloud-sql>
#   (4070, 15)
#  PosN: 1840, UnlN: 2025
#  Vector shape:  (3865, 1131)
# After SVD, the vector shape:  (3865, 499)
#   Running:=====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  2025 1216 809
#   The model score on POS samples is 0.952174
#  Simpu0=0.911499	Simpp0=0.996246
#  Simpn1=0.785215	Simpp1=0.995369
#  Relative CSV shape:  (2854, 15)
#
#
# 16 mailgun <mailgun>
#   (1592, 15)
#  PosN: 1088, UnlN: 416
#  Vector shape:  (1504, 671)
# After SVD, the vector shape:  (1504, 499)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  416 384 32
#   The model score on POS samples is 0.996324
#  Simpu0=0.963331	Simpp0=0.971573
#  Simpn1=0.953887	Simpp1=0.979618
#  Relative CSV shape:  (1208, 15)
#
#
# 17 urban-airship <urbanairship.com>
#   (881, 15)
#  PosN: 613, UnlN: 250
#  Vector shape:  (863, 367)
# After SVD, the vector shape:  (863, 366)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  250 148 102
#   The model score on POS samples is 0.990212
#  Simpu0=0.964815	Simpp0=0.990984
#  Simpn1=0.931775	Simpp1=0.990197
#  Relative CSV shape:  (733, 15)
#
#
# 18 woocommerce <woocommerce>
#   (21381, 15)
#  PosN: 18504, UnlN: 2086
#  Vector shape:  (20590, 1562)
# After SVD, the vector shape:  (20590, 499)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  2086 1713 373
#   The model score on POS samples is 0.998649
#  Simpu0=0.976919	Simpp0=0.999842
#  Simpn1=0.968084	Simpp1=0.999878
#  Relative CSV shape:  (19668, 15)
#
#
# 19 amazon-queue-service <amazon-sqs>
#   (13385, 15)
#  PosN: 313, UnlN: 13069
#  Vector shape:  (13382, 3496)
# After SVD, the vector shape:  (13382, 499)
#   Running:=====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  13069 12971 98
#   The model score on POS samples is 0.769968
#  Simpu0=0.225938	Simpp0=0.980829
#  Simpn1=0.185216	Simpp1=0.985928
#  Relative CSV shape:  (414, 15)
#
#
# 20 itunes-and-itunes-connect <itunesconnect>
#   (8226, 15)
#  PosN: 4653, UnlN: 3374
#  Vector shape:  (8027, 1227)
# After SVD, the vector shape:  (8027, 499)
#   Running:====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  3374 1166 2208
#   The model score on POS samples is 0.973136
#  Simpu0=0.974369	Simpp0=0.999196
#  Simpn1=0.972126	Simpp1=0.998942
#  Relative CSV shape:  (7060, 15)
#
#
# 21 tumblr <tumblr>
#   (3319, 15)
#  PosN: 1882, UnlN: 1299
#  Vector shape:  (3181, 1209)
# After SVD, the vector shape:  (3181, 499)
#   Running:====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  1299 619 680
#   The model score on POS samples is 0.988310
#  Simpu0=0.947166	Simpp0=0.988270
#  Simpn1=0.914595	Simpp1=0.995529
#  Relative CSV shape:  (2700, 15)
#
#
# 22 pubnub <pubnub>
#   (1136, 15)
#  PosN: 875, UnlN: 190
#  Vector shape:  (1065, 628)
# After SVD, the vector shape:  (1065, 499)
#   Running:=
# No iQ. All iUs are NEG.
#  Simpu0=0.921163	Simpp0=0.967828
#  Simpn1=0.921163	Simpp1=0.957787
#  Relative CSV shape:  (946, 15)
#
#
# 23 amazon-ses <amazon-ses>
#   (7813, 15)
#  PosN: 1118, UnlN: 6675
#  Vector shape:  (7793, 2951)
# After SVD, the vector shape:  (7793, 499)
#   Running:=========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  6675 6155 520
#   The model score on POS samples is 0.822004
#  Simpu0=0.841392	Simpp0=0.993910
#  Simpn1=0.829662	Simpp1=0.995313
#  Relative CSV shape:  (1658, 15)
#
#
# 24 vk <vk>
#   (5561, 15)
#  PosN: 242, UnlN: 5307
#  Vector shape:  (5549, 3066)
# After SVD, the vector shape:  (5549, 499)
#   Running:========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  5307 5186 121
#   The model score on POS samples is 0.570248
#  Simpu0=0.552810	Simpp0=0.865992
#  Simpn1=0.585607	Simpp1=0.900581
#  Relative CSV shape:  (375, 15)
#
#
# 25 linkedin <linkedin-api>
#   (6833, 15)
#  PosN: 927, UnlN: 5854
#  Vector shape:  (6781, 1819)
# After SVD, the vector shape:  (6781, 499)
#   Running:===========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  5854 4593 1261
#   The model score on POS samples is 0.669903
#  Simpu0=0.956104	Simpp0=0.996048
#  Simpn1=0.918106	Simpp1=0.998652
#  Relative CSV shape:  (2240, 15)
#
#
# 26 openlayers <openlayers>
#   (5768, 15)
#  PosN: 2937, UnlN: 2474
#  Vector shape:  (5411, 1181)
# After SVD, the vector shape:  (5411, 499)
#   Running:=======
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  2474 2246 228
#   The model score on POS samples is 0.864828
#  Simpu0=0.680918	Simpp0=0.995291
#  Simpn1=0.667458	Simpp1=0.995987
#  Relative CSV shape:  (3522, 15)
#
#
# 27 deezer <deezer>
#   (363, 15)
#  PosN: 197, UnlN: 57
#  Vector shape:  (254, 187)
# After SVD, the vector shape:  (254, 186)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  57 55 2
#   The model score on POS samples is 0.994924
#  Simpu0=0.632683	Simpp0=0.962460
#  Simpn1=0.606078	Simpp1=0.895459
#  Relative CSV shape:  (308, 15)
#
#
# 28 plunker <plunker>
#   (8374, 15)
#  PosN: 238, UnlN: 8119
#  Vector shape:  (8357, 1317)
# After SVD, the vector shape:  (8357, 499)
#   Running:=====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  8119 6852 1267
#   The model score on POS samples is 0.382353
#  Simpu0=0.942262	Simpp0=0.951775
#  Simpn1=0.950759	Simpp1=0.998178
#  Relative CSV shape:  (1522, 15)
#
#
# 29 sms <sms>
#   (41740, 15)
#  PosN: 6679, UnlN: 34985
#  Vector shape:  (41664, 6840)
# After SVD, the vector shape:  (41664, 499)
#   Running:==============
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  34985 28853 6132
#   The model score on POS samples is 0.790687
#  Simpu0=0.571905	Simpp0=0.997724
#  Simpn1=0.314192	Simpp1=0.999329
#  Relative CSV shape:  (12887, 15)
#
#
# 30 google-fusion-tables <google-fusion-tables>
#   (1539, 15)
#  PosN: 1169, UnlN: 170
#  Vector shape:  (1339, 479)
# After SVD, the vector shape:  (1339, 478)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  170 161 9
#   The model score on POS samples is 1.000000
#  Simpu0=0.973404	Simpp0=0.992422
#  Simpn1=0.973105	Simpp1=0.991873
#  Relative CSV shape:  (1378, 15)
#
#
# 31 google-checkout <google-checkout>
#   (1596, 15)
#  PosN: 334, UnlN: 1222
#  Vector shape:  (1556, 923)
# After SVD, the vector shape:  (1556, 499)
#   Running:========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  1222 1004 218
#   The model score on POS samples is 0.856287
#  Simpu0=0.732633	Simpp0=0.925803
#  Simpn1=0.508259	Simpp1=0.961421
#  Relative CSV shape:  (592, 15)
#
#
# 32 onelogin <onelogin>
#   (458, 15)
#  PosN: 260, UnlN: 154
#  Vector shape:  (414, 305)
# After SVD, the vector shape:  (414, 304)
#   Running:==
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  154 126 28
#   The model score on POS samples is 0.976923
#  Simpu0=0.726337	Simpp0=0.930357
#  Simpn1=0.557222	Simpp1=0.969210
#  Relative CSV shape:  (332, 15)
#
#
# 33 allegro <allegro>
#   (892, 15)
#  PosN: 349, UnlN: 536
#  Vector shape:  (885, 658)
# After SVD, the vector shape:  (885, 499)
#   Running:====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  536 355 181
#   The model score on POS samples is 0.982808
#  Simpu0=0.864122	Simpp0=0.980782
#  Simpn1=0.678659	Simpp1=0.990784
#  Relative CSV shape:  (537, 15)
#
#
# 34 coupon <coupon>
#   (3243, 15)
#  PosN: 305, UnlN: 2938
#  Vector shape:  (3243, 1450)
# After SVD, the vector shape:  (3243, 499)
#   Running:============
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  2938 2539 399
#   The model score on POS samples is 0.731148
#  Simpu0=0.792655	Simpp0=0.980143
#  Simpn1=0.558601	Simpp1=0.996837
#  Relative CSV shape:  (704, 15)
#
#
# 35 eventbrite <eventbrite>
#   (353, 15)
#  PosN: 182, UnlN: 82
#  Vector shape:  (264, 261)
# After SVD, the vector shape:  (264, 260)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  82 81 1
#   The model score on POS samples is 0.989011
#  Simpu0=0.641754	Simpp0=0.917332
#  Simpn1=0.639544	Simpp1=0.895562
#  Relative CSV shape:  (272, 15)
#
#
# 36 brightcove <brightcove>
#   (331, 15)
#  PosN: 223, UnlN: 78
#  Vector shape:  (301, 258)
# After SVD, the vector shape:  (301, 257)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  78 77 1
#   The model score on POS samples is 1.000000
#  Simpu0=0.863718	Simpp0=0.925784
#  Simpn1=0.858103	Simpp1=0.930748
#  Relative CSV shape:  (254, 15)
#
#
# 37 lastfm <last.fm>
#   (612, 15)
#  PosN: 277, UnlN: 327
#  Vector shape:  (604, 543)
# After SVD, the vector shape:  (604, 499)
#   Running:===
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  327 236 91
#   The model score on POS samples is 0.985560
#  Simpu0=0.907659	Simpp0=0.942047
#  Simpn1=0.855555	Simpp1=0.955048
#  Relative CSV shape:  (376, 15)
#
#
# 38 google-app-engine <google-app-engine>
#   (50022, 15)
#  PosN: 40056, UnlN: 7260
#  Vector shape:  (47316, 4895)
# After SVD, the vector shape:  (47316, 499)
#   Running:=====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  7260 4163 3097
#   The model score on POS samples is 0.994358
#  Simpu0=0.732043	Simpp0=0.999344
#  Simpn1=0.590628	Simpp1=0.999599
#  Relative CSV shape:  (45859, 15)
#
#
# 39 gravatar <gravatar>
#   (544, 15)
#  PosN: 210, UnlN: 325
#  Vector shape:  (535, 441)
# After SVD, the vector shape:  (535, 440)
#   Running:======
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  325 188 137
#   The model score on POS samples is 0.957143
#  Simpu0=0.911484	Simpp0=0.898800
#  Simpn1=0.698595	Simpp1=0.942579
#  Relative CSV shape:  (356, 15)
#
#
# 40 mailchimp <mailchimp>
#   (3152, 15)
#  PosN: 1950, UnlN: 1014
#  Vector shape:  (2964, 999)
# After SVD, the vector shape:  (2964, 499)
#   Running:==
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  1014 460 554
#   The model score on POS samples is 0.994359
#  Simpu0=0.963028	Simpp0=0.986620
#  Simpn1=0.921643	Simpp1=0.993900
#  Relative CSV shape:  (2692, 15)
#
#
# 41 buffer <buffer>
#   (114496, 15)
#  PosN: 5326, UnlN: 109164
#  Vector shape:  (114490, 10995)
# After SVD, the vector shape:  (114490, 499)
#   Running:=============
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  109164 106790 2374
#   The model score on POS samples is 0.119602
#  Simpu0=0.876811	Simpp0=0.989399
#  Simpn1=0.756401	Simpp1=0.995111
#  Relative CSV shape:  (7706, 15)
#
#
# 42 google-cloud-dns <google-cloud-dns>
#   (459, 15)
#  PosN: 103, UnlN: 332
#  Vector shape:  (435, 332)
# After SVD, the vector shape:  (435, 331)
#   Running:=======
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  332 273 59
#   The model score on POS samples is 0.825243
#  Simpu0=0.938604	Simpp0=0.939017
#  Simpn1=0.880968	Simpp1=0.964365
#  Relative CSV shape:  (186, 15)
#
#
# 43 amazon-s3 <amazon-s3>
#   (31507, 15)
#  PosN: 27176, UnlN: 3775
#  Vector shape:  (30951, 3670)
# After SVD, the vector shape:  (30951, 499)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  3775 1650 2125
#   The model score on POS samples is 0.999926
#  Simpu0=0.913004	Simpp0=0.999516
#  Simpn1=0.858403	Simpp1=0.999349
#  Relative CSV shape:  (29857, 15)
#
#
# 44 dailymotion <dailymotion-api>
#   (456, 15)
#  PosN: 140, UnlN: 253
#  Vector shape:  (393, 345)
# After SVD, the vector shape:  (393, 344)
#   Running:=====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  253 205 48
#   The model score on POS samples is 0.871429
#  Simpu0=0.890641	Simpp0=0.836229
#  Simpn1=0.775060	Simpp1=0.939722
#  Relative CSV shape:  (251, 15)
#
#
# 45 openx <openx>
#   (5062, 15)
#  PosN: 157, UnlN: 4879
#  Vector shape:  (5036, 1282)
# After SVD, the vector shape:  (5036, 499)
#   Running:====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  4879 4861 18
#   The model score on POS samples is 0.828025
#  Simpu0=0.040492	Simpp0=0.827979
#  Simpn1=0.035458	Simpp1=0.908831
#  Relative CSV shape:  (201, 15)
#
#
# 46 bigcommerce <bigcommerce>
#   (1367, 15)
#  PosN: 818, UnlN: 91
#  Vector shape:  (909, 476)
# After SVD, the vector shape:  (909, 475)
#   Running:=
# No iQ. All iUs are NEG.
#  Simpu0=0.801700	Simpp0=0.972373
#  Simpn1=0.801700	Simpp1=0.974967
#  Relative CSV shape:  (1276, 15)
#
#
# 47 google-drive <google-drive-sdk>
#   (25999, 15)
#  PosN: 8474, UnlN: 16056
#  Vector shape:  (24530, 4567)
# After SVD, the vector shape:  (24530, 499)
#   Running:========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  16056 12294 3762
#   The model score on POS samples is 0.901581
#  Simpu0=0.679635	Simpp0=0.993031
#  Simpn1=0.479961	Simpp1=0.997256
#  Relative CSV shape:  (13705, 15)
#
#
# 48 instagram-graph <instagram-graph-api>
#   (421, 15)
#  PosN: 72, UnlN: 343
#  Vector shape:  (415, 242)
# After SVD, the vector shape:  (415, 241)
#   Running:=====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  343 224 119
#   The model score on POS samples is 0.694444
#  Simpu0=0.933528	Simpp0=0.948313
#  Simpn1=0.903748	Simpp1=0.995941
#  Relative CSV shape:  (197, 15)
#
#
# 49 mixer <mixer>
#   (1710, 15)
#  PosN: 142, UnlN: 1568
#  Vector shape:  (1710, 1092)
# After SVD, the vector shape:  (1710, 499)
#   Running:=====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  1568 1467 101
#   The model score on POS samples is 0.373239
#  Simpu0=0.869026	Simpp0=0.953300
#  Simpn1=0.705440	Simpp1=0.974759
#  Relative CSV shape:  (243, 15)
#
#
# 50 xero <xero-api>
#   (536, 15)
#  PosN: 143, UnlN: 330
#  Vector shape:  (473, 525)
# After SVD, the vector shape:  (473, 471)
#   Running:====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  330 299 31
#   The model score on POS samples is 0.902098
#  Simpu0=0.688867	Simpp0=0.848636
#  Simpn1=0.578696	Simpp1=0.852620
#  Relative CSV shape:  (237, 15)
#
#
# 51 stripe <stripe-payments>
#   (12148, 15)
#  PosN: 4407, UnlN: 7381
#  Vector shape:  (11788, 3147)
# After SVD, the vector shape:  (11788, 499)
#   Running:======
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  7381 5895 1486
#   The model score on POS samples is 0.965056
#  Simpu0=0.563940	Simpp0=0.993385
#  Simpn1=0.419120	Simpp1=0.995762
#  Relative CSV shape:  (6253, 15)
#
#
# 52 facebook <facebook>
#   (148956, 15)
#  PosN: 79682, UnlN: 65727
#  Vector shape:  (145409, 7231)
# After SVD, the vector shape:  (145409, 499)
#   Running:=========================
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  65727 31394 34333
#   The model score on POS samples is 0.926997
#  Simpu0=0.905948	Simpp0=0.999700
#  Simpn1=0.747963	Simpp1=0.999743
#  Relative CSV shape:  (117562, 15)
#
#
# 53 openstack <openstack>
#   (3171, 15)
#  PosN: 2125, UnlN: 842
#  Vector shape:  (2967, 1092)
# After SVD, the vector shape:  (2967, 499)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  842 400 442
#   The model score on POS samples is 0.992000
#  Simpu0=0.785317	Simpp0=0.971216
#  Simpn1=0.715684	Simpp1=0.983948
#  Relative CSV shape:  (2771, 15)
#
#
# 54 geonames <geonames>
#   (385, 15)
#  PosN: 147, UnlN: 228
#  Vector shape:  (375, 372)
# After SVD, the vector shape:  (375, 371)
#   Running:===
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  228 117 111
#   The model score on POS samples is 0.986395
#  Simpu0=0.886494	Simpp0=0.798913
#  Simpn1=0.563935	Simpp1=0.866216
#  Relative CSV shape:  (268, 15)
#
#
# 55 multimap <multimap>
#   (1600, 15)
#  PosN: 641, UnlN: 959
#  Vector shape:  (1600, 736)
# After SVD, the vector shape:  (1600, 499)
#   Running:====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  959 485 474
#   The model score on POS samples is 0.964119
#  Simpu0=0.978986	Simpp0=0.990690
#  Simpn1=0.942039	Simpp1=0.995490
#  Relative CSV shape:  (1115, 15)
#
#
# 56 breadcrumbs <breadcrumbs>
#   (2331, 15)
#  PosN: 952, UnlN: 1375
#  Vector shape:  (2327, 1206)
# After SVD, the vector shape:  (2327, 499)
#   Running:=====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  1375 570 805
#   The model score on POS samples is 0.978992
#  Simpu0=0.943960	Simpp0=0.963609
#  Simpn1=0.827915	Simpp1=0.978835
#  Relative CSV shape:  (1761, 15)
#
#
# 57 mapbox <mapbox>
#   (4602, 15)
#  PosN: 3346, UnlN: 1131
#  Vector shape:  (4477, 1089)
# After SVD, the vector shape:  (4477, 499)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  1131 527 604
#   The model score on POS samples is 0.995816
#  Simpu0=0.844948	Simpp0=0.993738
#  Simpn1=0.891907	Simpp1=0.995052
#  Relative CSV shape:  (4075, 15)
#
#
# 58 digitalocean <digital-ocean>
#   (5499, 15)
#  PosN: 2087, UnlN: 3391
#  Vector shape:  (5478, 1833)
# After SVD, the vector shape:  (5478, 499)
#   Running:=========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  3391 1666 1725
#   The model score on POS samples is 0.925252
#  Simpu0=0.961936	Simpp0=0.974645
#  Simpn1=0.884808	Simpp1=0.989127
#  Relative CSV shape:  (3833, 15)
#
#
# 59 google-maps-android <google-maps-android-api-2>
#   (24249, 15)
#  PosN: 3270, UnlN: 20940
#  Vector shape:  (24210, 1903)
# After SVD, the vector shape:  (24210, 499)
#   Running:========================
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  20940 11469 9471
#   The model score on POS samples is 0.685321
#  Simpu0=0.963043	Simpp0=0.999339
#  Simpn1=0.991948	Simpp1=0.999899
#  Relative CSV shape:  (12780, 15)
#
#
# 60 pinterest <pinterest>
#   (2053, 15)
#  PosN: 748, UnlN: 1225
#  Vector shape:  (1973, 1030)
# After SVD, the vector shape:  (1973, 499)
#   Running:=========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  1225 800 425
#   The model score on POS samples is 0.905080
#  Simpu0=0.864397	Simpp0=0.965522
#  Simpn1=0.857465	Simpp1=0.970464
#  Relative CSV shape:  (1253, 15)
#
#
# 61 coinbase <coinbase-api>
#   (485, 15)
#  PosN: 272, UnlN: 151
#  Vector shape:  (423, 303)
# After SVD, the vector shape:  (423, 302)
#   Running:==
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  151 101 50
#   The model score on POS samples is 0.992647
#  Simpu0=0.851505	Simpp0=0.931468
#  Simpn1=0.768179	Simpp1=0.929892
#  Relative CSV shape:  (384, 15)
#
#
# 62 google-directions <google-direction>
#   (13692, 15)
#  PosN: 287, UnlN: 13401
#  Vector shape:  (13688, 4465)
# After SVD, the vector shape:  (13688, 499)
#   Running:==========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  13401 12868 533
#   The model score on POS samples is 0.268293
#  Simpu0=0.861787	Simpp0=0.980960
#  Simpn1=0.729590	Simpp1=0.994923
#  Relative CSV shape:  (824, 15)
#
#
# 63 google-cloud-print <google-cloud-print>
#   (681, 15)
#  PosN: 170, UnlN: 492
#  Vector shape:  (662, 595)
# After SVD, the vector shape:  (662, 499)
#   Running:===
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  492 442 50
#   The model score on POS samples is 0.900000
#  Simpu0=0.640357	Simpp0=0.924345
#  Simpn1=0.481811	Simpp1=0.939272
#  Relative CSV shape:  (239, 15)
#
#
# 64 flickr <flickr>
#   (2957, 15)
#  PosN: 1108, UnlN: 1790
#  Vector shape:  (2898, 1482)
# After SVD, the vector shape:  (2898, 499)
#   Running:=============
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  1790 1319 471
#   The model score on POS samples is 0.880866
#  Simpu0=0.898477	Simpp0=0.963754
#  Simpn1=0.859589	Simpp1=0.983499
#  Relative CSV shape:  (1638, 15)
#
#
# 65 vimeo <vimeo-api>
#   (3305, 15)
#  PosN: 547, UnlN: 2728
#  Vector shape:  (3275, 1178)
# After SVD, the vector shape:  (3275, 499)
#   Running:==========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  2728 2492 236
#   The model score on POS samples is 0.608775
#  Simpu0=0.863287	Simpp0=0.982928
#  Simpn1=0.843825	Simpp1=0.994218
#  Relative CSV shape:  (813, 15)
#
#
# 66 heroku <heroku>
#   (38000, 15)
#  PosN: 29625, UnlN: 7561
#  Vector shape:  (37186, 4027)
# After SVD, the vector shape:  (37186, 499)
#   Running:===
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  7561 3342 4219
#   The model score on POS samples is 0.995916
#  Simpu0=0.977028	Simpp0=0.999262
#  Simpn1=0.957821	Simpp1=0.999144
#  Relative CSV shape:  (34658, 15)
#
#
# 67 gmail <gmail-api>
#   (36419, 15)
#  PosN: 2380, UnlN: 33733
#  Vector shape:  (36113, 4728)
# After SVD, the vector shape:  (36113, 499)
#   Running:==================
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  33733 30140 3593
#   The model score on POS samples is 0.606723
#  Simpu0=0.782753	Simpp0=0.992361
#  Simpn1=0.879903	Simpp1=0.997189
#  Relative CSV shape:  (6279, 15)
#
#
# 68 soundcloud <soundcloud>
#   (2885, 15)
#  PosN: 1739, UnlN: 829
#  Vector shape:  (2568, 1037)
# After SVD, the vector shape:  (2568, 499)
#   Running:===
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  829 475 354
#   The model score on POS samples is 0.988499
#  Simpu0=0.823931	Simpp0=0.988612
#  Simpn1=0.815546	Simpp1=0.990051
#  Relative CSV shape:  (2410, 15)
#
#
# 69 rackspace-cloud-servers <rackspace-cloud>
#   (915, 15)
#  PosN: 327, UnlN: 583
#  Vector shape:  (910, 763)
# After SVD, the vector shape:  (910, 499)
#   Running:===========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  583 463 120
#   The model score on POS samples is 0.847095
#  Simpu0=0.931567	Simpp0=0.929441
#  Simpn1=0.849302	Simpp1=0.961153
#  Relative CSV shape:  (452, 15)
#
#
# 70 google-maps-places <google-places-api>
#   (11876, 15)
#  PosN: 3864, UnlN: 7730
#  Vector shape:  (11594, 3235)
# After SVD, the vector shape:  (11594, 499)
#   Running:===========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  7730 5187 2543
#   The model score on POS samples is 0.857402
#  Simpu0=0.938037	Simpp0=0.996667
#  Simpn1=0.856204	Simpp1=0.998626
#  Relative CSV shape:  (6689, 15)
#
#
# 71 plivo <plivo>
#   (195, 15)
#  PosN: 142, UnlN: 41
#  Vector shape:  (183, 169)
# After SVD, the vector shape:  (183, 168)
#   Running:=
# No iQ. All iUs are NEG.
#  Simpu0=0.621795	Simpp0=0.758350
#  Simpn1=0.621795	Simpp1=0.814027
#  Relative CSV shape:  (154, 15)
#
#
# 72 sendgrid <sendgrid>
#   (2633, 15)
#  PosN: 1811, UnlN: 757
#  Vector shape:  (2568, 893)
# After SVD, the vector shape:  (2568, 499)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  757 295 462
#   The model score on POS samples is 0.997791
#  Simpu0=0.958775	Simpp0=0.984179
#  Simpn1=0.946380	Simpp1=0.991293
#  Relative CSV shape:  (2338, 15)
#
#
# 73 facebook-ads <facebook-ads-api>
#   (6052, 15)
#  PosN: 680, UnlN: 5324
#  Vector shape:  (6004, 1872)
# After SVD, the vector shape:  (6004, 499)
#   Running:=============
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  5324 4544 780
#   The model score on POS samples is 0.692647
#  Simpu0=0.891384	Simpp0=0.996657
#  Simpn1=0.835517	Simpp1=0.997571
#  Relative CSV shape:  (1508, 15)
#
#
# 74 google-maps <google-maps>
#   (89057, 15)
#  PosN: 57792, UnlN: 29367
#  Vector shape:  (87159, 5100)
# After SVD, the vector shape:  (87159, 499)
#   Running:=======
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  29367 8929 20438
#   The model score on POS samples is 0.984288
#  Simpu0=0.974044	Simpp0=0.999686
#  Simpn1=0.968894	Simpp1=0.999731
#  Relative CSV shape:  (80128, 15)
#
#
# 75 ilist <ilist>
#   (4992, 15)
#  PosN: 288, UnlN: 4704
#  Vector shape:  (4992, 2162)
# After SVD, the vector shape:  (4992, 499)
#   Running:===========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  4704 4356 348
#   The model score on POS samples is 0.329861
#  Simpu0=0.953928	Simpp0=0.976317
#  Simpn1=0.932339	Simpp1=0.995202
#  Relative CSV shape:  (636, 15)
#
#
# 76 authorizenet <authorize.net>
#   (1383, 15)
#  PosN: 938, UnlN: 330
#  Vector shape:  (1268, 507)
# After SVD, the vector shape:  (1268, 499)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  330 193 137
#   The model score on POS samples is 0.997868
#  Simpu0=0.923198	Simpp0=0.973366
#  Simpn1=0.822477	Simpp1=0.969104
#  Relative CSV shape:  (1190, 15)
#
#
# 77 2checkout <2checkout>
#   (174, 15)
#  PosN: 116, UnlN: 39
#  Vector shape:  (155, 135)
# After SVD, the vector shape:  (155, 134)
#   Running:=
# No iQ. All iUs are NEG.
#  Simpu0=0.835854	Simpp0=0.821042
#  Simpn1=0.835854	Simpp1=0.874011
#  Relative CSV shape:  (135, 15)
#
#
# 78 musicbrainz <musicbrainz>
#   (177, 15)
#  PosN: 87, UnlN: 78
#  Vector shape:  (165, 191)
# After SVD, the vector shape:  (165, 163)
#   Running:==
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  78 55 23
#   The model score on POS samples is 1.000000
#  Simpu0=0.776693	Simpp0=0.763167
#  Simpn1=0.560842	Simpp1=0.811018
#  Relative CSV shape:  (122, 15)
#
#
# 79 opensocial <opensocial>
#   (219, 15)
#  PosN: 160, UnlN: 52
#  Vector shape:  (212, 218)
# After SVD, the vector shape:  (212, 210)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  52 43 9
#   The model score on POS samples is 1.000000
#  Simpu0=0.717221	Simpp0=0.816489
#  Simpn1=0.645132	Simpp1=0.866562
#  Relative CSV shape:  (176, 15)
#
#
# 80 openstreetmap <openstreetmap>
#   (3576, 15)
#  PosN: 2864, UnlN: 596
#  Vector shape:  (3460, 1199)
# After SVD, the vector shape:  (3460, 499)
#   Running:==
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  596 330 266
#   The model score on POS samples is 0.999651
#  Simpu0=0.927476	Simpp0=0.986275
#  Simpn1=0.860564	Simpp1=0.990892
#  Relative CSV shape:  (3246, 15)
#
#
# 81 imgur <imgur>
#   (2463, 15)
#  PosN: 395, UnlN: 2039
#  Vector shape:  (2434, 1762)
# After SVD, the vector shape:  (2434, 499)
#   Running:=========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  2039 1915 124
#   The model score on POS samples is 0.711392
#  Simpu0=0.684266	Simpp0=0.944413
#  Simpn1=0.658368	Simpp1=0.971286
#  Relative CSV shape:  (548, 15)
#
#
# 82 paypal <paypal>
#   (23084, 15)
#  PosN: 16531, UnlN: 4832
#  Vector shape:  (21363, 2405)
# After SVD, the vector shape:  (21363, 499)
#   Running:====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  4832 1784 3048
#   The model score on POS samples is 0.993406
#  Simpu0=0.924758	Simpp0=0.998932
#  Simpn1=0.861805	Simpp1=0.999043
#  Relative CSV shape:  (21300, 15)
#
#
# 83 twitter <twitter>
#   (157891, 15)
#  PosN: 21493, UnlN: 135544
#  Vector shape:  (157037, 6947)
# After SVD, the vector shape:  (157037, 499)
#   Running:============================================
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  135544 123693 11851
#   The model score on POS samples is 0.873075
#  Simpu0=0.271597	Simpp0=0.997869
#  Simpn1=0.211621	Simpp1=0.998875
#  Relative CSV shape:  (34198, 15)
#
#
# 84 mapquest <mapquest>
#   (467, 15)
#  PosN: 250, UnlN: 191
#  Vector shape:  (441, 321)
# After SVD, the vector shape:  (441, 320)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  191 88 103
#   The model score on POS samples is 1.000000
#  Simpu0=0.865552	Simpp0=0.915768
#  Simpn1=0.804609	Simpp1=0.948226
#  Relative CSV shape:  (379, 15)
#
#
# 85 aws-cloud9 <aws-cloud9>
#   (192, 15)
#  PosN: 88, UnlN: 101
#  Vector shape:  (189, 228)
# After SVD, the vector shape:  (189, 187)
#   Running:===
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  101 79 22
#   The model score on POS samples is 0.931818
#  Simpu0=0.902904	Simpp0=0.897128
#  Simpn1=0.808324	Simpp1=0.910595
#  Relative CSV shape:  (113, 15)
#
#
# 86 amazon-ec2 <amazon-ec2>
#   (27621, 15)
#  PosN: 23452, UnlN: 3666
#  Vector shape:  (27118, 3780)
# After SVD, the vector shape:  (27118, 499)
#   Running:==
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  3666 1699 1967
#   The model score on POS samples is 0.999147
#  Simpu0=0.959238	Simpp0=0.999547
#  Simpn1=0.907741	Simpp1=0.999490
#  Relative CSV shape:  (25922, 15)
#
#
# 87 google-plus <google-plus>
#   (9150, 15)
#  PosN: 3934, UnlN: 4949
#  Vector shape:  (8883, 2944)
# After SVD, the vector shape:  (8883, 499)
#   Running:================
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  4949 3445 1504
#   The model score on POS samples is 0.934926
#  Simpu0=0.901948	Simpp0=0.989314
#  Simpn1=0.841859	Simpp1=0.994428
#  Relative CSV shape:  (5705, 15)
#
#
# 88 geocoder <google-geocoder>
#   (3957, 15)
#  PosN: 898, UnlN: 3044
#  Vector shape:  (3942, 1069)
# After SVD, the vector shape:  (3942, 499)
#   Running:=======
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  3044 2068 976
#   The model score on POS samples is 0.861915
#  Simpu0=0.844364	Simpp0=0.982527
#  Simpn1=0.522589	Simpp1=0.995576
#  Relative CSV shape:  (1889, 15)
#
#
# 89 mailjet <mailjet>
#   (166, 15)
#  PosN: 114, UnlN: 43
#  Vector shape:  (157, 165)
# After SVD, the vector shape:  (157, 155)
#   Running:=
# No iQ. All iUs are NEG.
#  Simpu0=0.757342	Simpp0=0.805707
#  Simpn1=0.757342	Simpp1=0.860989
#  Relative CSV shape:  (123, 15)
#
#
# 90 google-static-maps <google-static-maps>
#   (1359, 15)
#  PosN: 291, UnlN: 1038
#  Vector shape:  (1329, 756)
# After SVD, the vector shape:  (1329, 499)
#   Running:=====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  1038 773 265
#   The model score on POS samples is 0.742268
#  Simpu0=0.939503	Simpp0=0.984753
#  Simpn1=0.928205	Simpp1=0.994634
#  Relative CSV shape:  (586, 15)
#
#
# 91 reddit <reddit>
#   (3428, 15)
#  PosN: 792, UnlN: 2621
#  Vector shape:  (3413, 1876)
# After SVD, the vector shape:  (3413, 499)
#   Running:=======
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  2621 2275 346
#   The model score on POS samples is 0.734848
#  Simpu0=0.793243	Simpp0=0.977052
#  Simpn1=0.717135	Simpp1=0.988233
#  Relative CSV shape:  (1153, 15)
#
#
# 92 google-earth <google-earth>
#   (2737, 15)
#  PosN: 821, UnlN: 1891
#  Vector shape:  (2712, 1395)
# After SVD, the vector shape:  (2712, 499)
#   Running:===============
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  1891 1426 465
#   The model score on POS samples is 0.867235
#  Simpu0=0.786801	Simpp0=0.993227
#  Simpn1=0.650034	Simpp1=0.993816
#  Relative CSV shape:  (1311, 15)
#
#
# 93 telegram-bot <telegram-bot>
#   (3016, 15)
#  PosN: 1739, UnlN: 1182
#  Vector shape:  (2921, 899)
# After SVD, the vector shape:  (2921, 499)
#   Running:==
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  1182 455 727
#   The model score on POS samples is 0.991949
#  Simpu0=0.932662	Simpp0=0.997238
#  Simpn1=0.923446	Simpp1=0.997801
#  Relative CSV shape:  (2561, 15)
#
#
# 94 dropbox <dropbox-api>
#   (11529, 15)
#  PosN: 1991, UnlN: 9414
#  Vector shape:  (11405, 3882)
# After SVD, the vector shape:  (11405, 499)
#   Running:==========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  9414 8268 1146
#   The model score on POS samples is 0.705676
#  Simpu0=0.928930	Simpp0=0.992825
#  Simpn1=0.879423	Simpp1=0.996812
#  Relative CSV shape:  (3261, 15)
#
#
# 95 recurly <recurly>
#   (192, 15)
#  PosN: 108, UnlN: 43
#  Vector shape:  (151, 139)
# After SVD, the vector shape:  (151, 138)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  43 42 1
#   The model score on POS samples is 1.000000
#  Simpu0=0.537188	Simpp0=0.857612
#  Simpn1=0.539528	Simpp1=0.815237
#  Relative CSV shape:  (150, 15)
#
#
# 96 rhapsody <rhapsody>
#   (191, 15)
#  PosN: 124, UnlN: 50
#  Vector shape:  (174, 256)
# After SVD, the vector shape:  (174, 172)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  50 47 3
#   The model score on POS samples is 1.000000
#  Simpu0=0.622615	Simpp0=0.856802
#  Simpn1=0.570385	Simpp1=0.853621
#  Relative CSV shape:  (144, 15)
#
#
# 97 mandrill <mandrill>
#   (1283, 15)
#  PosN: 847, UnlN: 362
#  Vector shape:  (1209, 598)
# After SVD, the vector shape:  (1209, 499)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  362 200 162
#   The model score on POS samples is 0.996458
#  Simpu0=0.942938	Simpp0=0.970987
#  Simpn1=0.893935	Simpp1=0.984163
#  Relative CSV shape:  (1083, 15)
#
#
# 98 twilio <twilio-api>
#   (6679, 15)
#  PosN: 1040, UnlN: 5620
#  Vector shape:  (6660, 1376)
# After SVD, the vector shape:  (6660, 499)
#   Running:=============
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  5620 3479 2141
#   The model score on POS samples is 0.716346
#  Simpu0=0.982186	Simpp0=0.997806
#  Simpn1=0.969963	Simpp1=0.999448
#  Relative CSV shape:  (3200, 15)
#
#
# 99 google-geocoding <google-geocoding-api>
#   (3428, 15)
#  PosN: 571, UnlN: 2795
#  Vector shape:  (3366, 891)
# After SVD, the vector shape:  (3366, 499)
#   Running:==========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  2795 1524 1271
#   The model score on POS samples is 0.728546
#  Simpu0=0.956952	Simpp0=0.987627
#  Simpn1=0.959363	Simpp1=0.997747
#  Relative CSV shape:  (1904, 15)
#
#
# 100 foursquare <foursquare>
#   (2210, 15)
#  PosN: 1146, UnlN: 708
#  Vector shape:  (1854, 894)
# After SVD, the vector shape:  (1854, 499)
#   Running:====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  708 387 321
#   The model score on POS samples is 0.988656
#  Simpu0=0.699461	Simpp0=0.977581
#  Simpn1=0.689466	Simpp1=0.979220
#  Relative CSV shape:  (1823, 15)
#
#
# 101 marketo <marketo>
#   (317, 15)
#  PosN: 169, UnlN: 77
#  Vector shape:  (246, 246)
# After SVD, the vector shape:  (246, 244)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  77 62 15
#   The model score on POS samples is 1.000000
#  Simpu0=0.676217	Simpp0=0.746985
#  Simpn1=0.601785	Simpp1=0.925679
#  Relative CSV shape:  (255, 15)
#
#
# 102 google-adwords <google-adwords>
#   (2135, 15)
#  PosN: 1426, UnlN: 482
#  Vector shape:  (1908, 803)
# After SVD, the vector shape:  (1908, 499)
#   Running:=
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  482 297 185
#   The model score on POS samples is 0.995091
#  Simpu0=0.927664	Simpp0=0.974393
#  Simpn1=0.855805	Simpp1=0.980847
#  Relative CSV shape:  (1838, 15)
#
#
# 103 google-mirror <google-mirror-api>
#   (997, 15)
#  PosN: 375, UnlN: 546
#  Vector shape:  (921, 858)
# After SVD, the vector shape:  (921, 499)
#   Running:===
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  546 510 36
#   The model score on POS samples is 0.981333
#  Simpu0=0.374690	Simpp0=0.994846
#  Simpn1=0.203190	Simpp1=0.995691
#  Relative CSV shape:  (487, 15)
#
#
# 104 google-street-view-image <google-street-view>
#   (1501, 15)
#  PosN: 633, UnlN: 848
#  Vector shape:  (1481, 631)
# After SVD, the vector shape:  (1481, 499)
#   Running:=========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  848 486 362
#   The model score on POS samples is 0.925750
#  Simpu0=0.983861	Simpp0=0.992165
#  Simpn1=0.912312	Simpp1=0.996953
#  Relative CSV shape:  (1015, 15)

# %% [markdown]
# 结果汇总4
# pu          pn          pp0         pp1
# 0.939503    0.928205    0.984753    0.994634    0.742268
# 0.793243    0.717135    0.977052    0.988233    0.734848
# 0.786801    0.650034    0.993227    0.993816    0.867235
# 0.932662    0.923446    0.997238    0.997801    0.991949
# 0.928930    0.879423    0.992825    0.996812    0.705676
#  0.537188    0.539528    0.857612    0.815237    1.000000
# 0.622615    0.570385    0.856802    0.853621    1.000000
# 0.942938    0.893935    0.970987    0.984163    0.996458
# 0.982186    0.969963    0.997806    0.999448    0.716346
#  0.956952    0.959363    0.987627    0.997747    0.728546
# 0.699461    0.689466    0.977581    0.979220    0.988656
# 0.676217    0.601785    0.746985    0.925679    1.000000
# 0.927664    0.855805    0.974393    0.980847    0.995091
# 0.374690    0.203190    0.994846    0.995691    0.981333
# 0.983861    0.912312    0.992165    0.996953    0.925750

# %% [markdown]
# 结果汇总3
# pu          pn          pp0         pp1
# 0.864397    0.857465    0.965522    0.970464    0.905080
# 0.851505    0.768179    0.931468    0.929892    0.992647
#  0.861787    0.729590    0.980960    0.994923    0.268293
# 0.640357    0.481811    0.924345    0.939272    0.900000
# 0.898477    0.859589    0.963754    0.983499    0.880866
# 0.863287    0.843825    0.982928    0.994218    0.608775
# 0.977028    0.957821    0.999262    0.999144    0.995916
#  0.782753    0.879903    0.992361    0.997189    0.606723
# 0.823931    0.815546    0.988612    0.990051    0.988499
# 0.931567    0.849302    0.929441    0.961153    0.847095
# 0.938037    0.856204    0.996667    0.998626    0.857402
# 0.621795    0.621795    0.758350    0.814027    -
# 0.958775    0.946380    0.984179    0.991293    0.997791
# 0.891384    0.835517    0.996657    0.997571    0.692647
# 0.974044    0.968894    0.999686    0.999731    0.984288
#  0.953928    0.932339    0.976317    0.995202    0.329861
# 0.923198    0.822477    0.973366    0.969104    0.997868
# 0.835854    0.835854    0.821042    0.874011    -
# 0.776693    0.560842    0.763167    0.811018    1.000000
# 0.717221    0.645132    0.816489    0.866562    1.000000
# 0.927476    0.860564    0.986275    0.990892    0.999651
# 0.684266    0.658368    0.944413    0.971286    0.711392
# 0.924758    0.861805    0.998932    0.999043    0.993406
# 0.271597    0.211621    0.997869    0.998875    0.873075
# 0.865552    0.804609    0.915768    0.948226    1.000000
# 0.902904    0.808324    0.897128    0.910595    0.931818
# 0.959238    0.907741    0.999547    0.999490    0.999147
# 0.901948    0.841859    0.989314    0.994428    0.934926
# 0.844364    0.522589    0.982527    0.995576    0.861915
# 0.757342    0.757342    0.805707    0.860989    -

# %% [markdown]
# 结果汇总2
# pu          pn          pp0         pp1
# 0.973404    0.973105    0.992422    0.991873    1.000000
# 0.732633    0.508259    0.925803    0.961421    0.856287
# 0.726337    0.557222    0.930357    0.969210    0.976923
# 0.864122    0.678659    0.980782    0.990784    0.982808
# 0.792655    0.558601    0.980143    0.996837    0.731148
# 0.641754    0.639544    0.917332    0.895562    0.989011
# 0.863718    0.858103    0.925784    0.930748    1.000000
# 0.907659    0.855555    0.942047    0.955048    0.985560
# 0.732043    0.590628    0.999344    0.999599    0.994358
# 0.911484    0.698595    0.898800    0.942579    0.957143
# 0.963028    0.921643    0.986620    0.993900    0.994359
#  0.876811    0.756401    0.989399    0.995111    0.119602
# 0.938604    0.880968    0.939017    0.964365    0.825243
# 0.913004    0.858403    0.999516    0.999349    0.999926
# 0.890641    0.775060    0.836229    0.939722    0.871429
# 0.040492    0.035458    0.827979    0.908831    0.828025
# 0.801700    0.801700    0.972373    0.974967    -
# 0.679635    0.479961    0.993031    0.997256    0.901581
# 0.933528    0.903748    0.948313    0.995941    0.694444
#  0.869026    0.705440    0.953300    0.974759    0.373239
# 0.688867    0.578696    0.848636    0.852620    0.902098
# 0.563940    0.419120    0.993385    0.995762    0.965056
# 0.905948    0.747963    0.999700    0.999743    0.926997
# 0.785317    0.715684    0.971216    0.983948    0.992000
# 0.886494    0.563935    0.798913    0.866216    0.986395
# 0.978986    0.942039    0.990690    0.995490    0.964119
# 0.943960    0.827915    0.963609    0.978835    0.978992
#  0.844948    0.891907    0.993738    0.995052    0.995816
# 0.961936    0.884808    0.974645    0.989127    0.925252
#  0.963043    0.991948    0.999339    0.999899    0.685321

# %% [markdown]
# 结果汇总1
# pu          pn          pp0         pp1
# 0.987634    0.983138    0.999138    0.999193    0.996703
#  0.889959    0.881093    0.906461    0.901620    0.037037
# 0.917585    0.862606    0.991948    0.996121    0.956069
# 0.888981    0.820417    0.867917    0.865363    0.952381
#  0.789130    0.713352    0.896626    0.913337    0.376437
#  0.888934    0.909027    0.998182    0.999252    0.743900
# 0.884686    0.761090    0.989057    0.989629    0.994676
# 0.799822    0.791363    0.910774    0.922810    1.000000
# 0.547900    0.485566    0.921762    0.954095    0.990847
# 0.852431    0.753512    0.928634    0.940360    0.983133
# 0.877079    0.855759    0.942892    0.990128    0.629630
# 0.958020    0.840487    0.995331    0.997008    0.963455
# 0.954011    0.916756    0.962899    0.985225    0.927757
# 0.851684    0.846418    0.840327    0.834058    0.951389
# 0.973719    0.942340    0.996962    0.996313    0.999334
# 0.911499    0.785215    0.996246    0.995369    0.952174
# 0.963331    0.953887    0.971573    0.979618    0.996324
# 0.964815    0.931775    0.990984    0.990197    0.990212
# 0.976919    0.968084    0.999842    0.999878    0.998649
# 0.225938    0.185216    0.980829    0.985928    0.769968
# 0.974369    0.972126    0.999196    0.998942    0.973136
# 0.947166    0.914595    0.988270    0.995529    0.988310
# 0.921163    0.921163    0.967828    0.957787    -
# 0.841392    0.829662    0.993910    0.995313    0.822004
#  0.552810    0.585607    0.865992    0.900581    0.570248
# 0.956104    0.918106    0.996048    0.998652    0.669903
# 0.680918    0.667458    0.995291    0.995987    0.864828
# 0.632683    0.606078    0.962460    0.895459    0.994924
#  0.942262    0.950759    0.951775    0.998178    0.382353
# 0.571905    0.314192    0.997724    0.999329    0.790687

# %% [markdown]
# 结果修正：
# 15 yahoo-mail <yahoo-mail>
#   (3626, 15)
#  PosN: 135, UnlN: 3487
#  Vector shape:  (3622, 1407)
# After SVD, the vector shape:  (3622, 499)
#   Running:============
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  3487 3387 100
#   The model score on POS samples is 0.659259
#  Simpu0=0.889959	Simpp0=0.906461
#  Simpn1=0.856731	Simpp1=0.950006
#  Relative CSV shape:  (239, 15)
#
#
# 7 zipcode <zipcode>
#   (3706, 15)
#  PosN: 348, UnlN: 3353
#  Vector shape:  (3701, 1747)
# After SVD, the vector shape:  (3701, 999)
#   Running:=====
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  3353 2376 977
#   The model score on POS samples is 1.000000
#  Simpu0=0.789130	Simpp0=0.896626
#  Simpn1=0.748105	Simpp1=0.971357
#  Relative CSV shape:  (1330, 15)
#
#
#
# 52 youtube <youtube-api>
#   (45527, 15)
#  PosN: 8442, UnlN: 36315
#  Vector shape:  (44757, 6211)
# After SVD, the vector shape:  (44757, 499)
#   Running:=========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  36315 29637 6678
#   The model score on POS samples is 0.668088
#  Simpu0=0.888934	Simpp0=0.998182
#  Simpn1=0.884491	Simpp1=0.999504
#  Relative CSV shape:  (15890, 15)
#
# 36 plunker <plunker>
#   (8374, 15)
#  PosN: 238, UnlN: 8119
#  Vector shape:  (8357, 1317)
# After SVD, the vector shape:  (8357, 999)
#   Running:===========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  8119 6354 1765
#   The model score on POS samples is 0.815126
#  Simpu0=0.942262	Simpp0=0.951775
#  Simpn1=0.963020	Simpp1=0.999006
#  Relative CSV shape:  (2020, 15)
#
#
# 81 buffer <buffer>
#   (114496, 15)
#  PosN: 5326, UnlN: 109164
#  Vector shape:  (114490, 10995)
# After SVD, the vector shape:  (114490, 499)
#   Running:============
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  109164 97360 11804
#   The model score on POS samples is 0.858806
#  Simpu0=0.876811	Simpp0=0.989399
#  Simpn1=0.810531	Simpp1=0.997617
#  Relative CSV shape:  (17136, 15)
#
#
#
# 75 mixer <mixer>
#   (1710, 15)
#  PosN: 142, UnlN: 1568
#  Vector shape:  (1710, 1092)
# After SVD, the vector shape:  (1710, 499)
#   Running:========
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  1568 1277 291
#   The model score on POS samples is 1.000000
#  Simpu0=0.869026	Simpp0=0.953300
#  Simpn1=0.797100	Simpp1=0.982495
#  Relative CSV shape:  (433, 15)
#
# 8 google-directions <google-direction>
#   (13692, 15)
#  PosN: 287, UnlN: 13401
#  Vector shape:  (13688, 4465)
# After SVD, the vector shape:  (13688, 499)
#   Running:=======
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  13401 11584 1817
#   The model score on POS samples is 0.993031
#  Simpu0=0.861787	Simpp0=0.980960
#  Simpn1=0.734504	Simpp1=0.998929
#  Relative CSV shape:  (2108, 15)
#
# 38 ilist <ilist>
#   (4992, 15)
#  PosN: 288, UnlN: 4704
#  Vector shape:  (4992, 2162)
# After SVD, the vector shape:  (4992, 499)
#   Running:======
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  4704 3594 1110
#   The model score on POS samples is 0.996528
#  Simpu0=0.953928	Simpp0=0.976317
#  Simpn1=0.946811	Simpp1=0.996300
#  Relative CSV shape:  (1398, 15)
#
# 91 google-geocoding <google-geocoding-api>
#   (3428, 15)
#  PosN: 571, UnlN: 2795
#  Vector shape:  (3366, 891)
# After SVD, the vector shape:  (3366, 499)
#   Running:======
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  2795 1489 1306
#   The model score on POS samples is 1.000000
#  Simpu0=0.956952	Simpp0=0.987627
#  Simpn1=0.950414	Simpp1=0.998655
#  Relative CSV shape:  (1939, 15)
#
# 89 vk <vk>
#   (5561, 15)
#  PosN: 242, UnlN: 5307
#  Vector shape:  (5549, 3066)
# After SVD, the vector shape:  (5549, 499)
#   Running:============
#   No iW. All iQs are POS.
#   iU, iRN, iQ:  5307 5046 261
#   The model score on POS samples is 0.896694
#  Simpu0=0.552810	Simpp0=0.865992
#  Simpn1=0.618377	Simpp1=0.890789
#  Relative CSV shape:  (515, 15)
